# %%
1. import re
input = 'Python Exercises, PHP exercises.'
print(re.sub("[ ,.]", ":", input))

2. import re

input = "Find all the words starting with letter a and e like aerosol erosion aeroplane elephant"

result = re.findall("[ae]\w+", input)

print(result)

3. import re
pattern = re.compile(r"\b\w{4,}\b")
input = 'a function in python to find all words that are at least 4 characters long in a string'
print(pattern.findall(input))

4. import re
pattern = re.compile(r"\b\w{3,5}\b")
input = 'a function in python to find all three, four, and five character words in a string.'
print(pattern.findall(input))

5. import re
pattern = re.compile(r" ?\([^)]+\)")
list = ["example (.com)", "hr@fliprobo (.com)", "github (.com)", "Hello (Data Science World)", "Data (Scientist)"]
for item in list:
    print(pattern.sub("", item))

6.import re
file = open("6_ass4.txt", "r")
readfile =file.read()
print(re.sub(r" ?\([^)]+\)", "", readfile))

7. import re
input = "ImportanceOfRegularExpressionsInPython"
search = re.findall('[A-Z][^A-Z]*', input)
print(search)



8. import re
def spacecapsword(str1):
  return re.sub(r"(\w)([0-9])", r"\1 \2", str1)

print(spacecapsword("MyNameisPython"))
print(spacecapsword("MyNameis4Python"))
print(spacecapsword("MyNameis4Python"))

9. import re
def spacecapsnumsword(str1):
  x=re.sub(r"(\w)([A-Z])", r"\1 \2", str1)
  return re.sub(r"(\w)([0-9])", r"\1 \2", x)

print(spacecapsnumsword("MyNameis4Python"))
print(spacecapsnumsword("MyNameis4Python"))
print(spacecapsnumsword("MyNameis4Python"))

10. import re
file = open("10_ass4.txt", "r")
readfile =file.read()
match = re.findall(r'[\w.+-]+@[\w-]+\.[\w.-]+', readfile)
print(match) 

11. import re
def check_match(input):
        patterns = '^[a-zA-Z0-9_]*$'
        if re.search(patterns,  input):
                return 'Got a corresponding pattern'
        else:
                return('Didnt get a corresponding pattern')

print(check_match("Python program to match a string that contains only upper and lowercase letters, numbers, and underscores."))
print(check_match("Pythonprogramtomatchastringthatcontainsonlyupperandlowercaselettersnumbersandunderscores_1"))

12. import re
def numb_start(number):
    check = re.compile(r"^6")
    if check.match(number):
        return ("Number is starting with 6")
    else:
        return ("Number is not starting with 6")
print(numb_start('743'))
print(numb_start('641'))

13. import re
IP_address = "547.065.01.457"
removal_of_leading_zeroes = re.sub('\.[0]*', '.', IP_address)
print(removal_of_leading_zeroes)

14. import re 

file = open("14_ass4.txt", "r")
readfile =file.read()
regex = r"([a-zA-Z]+) (\d+[a-z][a-z]) (\d+)"
match = re.search(regex,readfile) 
   
if match != None: 
    
    x=match.start()
    y=match.end() 
   
    
    print(readfile[x:y])
   
else: 
    print ("There are no dates")

15. import re
Words = [ 'fox', 'dog', 'horse' ]
String = 'The quick brown fox jumps over the lazy dog.'
for word in Words:
    if re.search(word, String):
        print(word ,"Matched!")
    else:
        print(word ,"Not Matched!")

16. import re
word = 'fox'
string = 'The quick brown fox jumps over the lazy dog.'
index = re.search(word, string)
starting_index = index.start()
ending_index = index.end()
print('Found "%s" in "%s" from %d to %d ' % \
    (index.re.pattern, index.string, starting_index, ending_index))

17. import re
string = 'Python exercises, PHP exercises, C# exercises'
substring = 'exercises'
for result in re.findall(substring, string):
    print('Found "%s"' % result)

18.  import re
string = 'a python program to find the occurrence and position of the python substrings within a python string.'
word = 'python'
for result in re.finditer(word, string):
    start_index = result.start()
    end_index = result.end()
    print('Found "%s" at %d:%d' % (string[start_index:end_index], start_index, end_index))

19. import re
def new_format(input):
        return re.sub(r'(\d{4})-(\d{1,2})-(\d{1,2})', '\\3-\\2-\\1', input)
sample_date = "2023-08-17"
print("original format : ",sample_date)
print("new format: ",new_format(sample_date))


20. import re
string = "Today's temperature is between 40.5 and 40.57 degrees."
pattern= re.compile("\d+\.\d{1,2}")
result=pattern.findall(string)
print(result)

21. import re

string = "a Python program to separate and print the numbers like 47 and their position of a given string."

for numb in re.finditer("\d+", string):
    print(numb.group(0))
    print("Index position:", numb.start())

22. import re
 
def Find_max(input):
     numb = re.findall('\d+',input)
     numb = map(int,numb)
 
     print(max(numb))
 
if __name__ == "__main__":
    input = 'My marks in each semester are: 947, 896, 926, 524, 734, 950, 642'
    Find_max(input)

23. import re
def space_after_capital(str1):
  return re.sub(r"(\w)([A-Z])", r"\1 \2", str1)

print(space_after_capital("RegularExpressionIsAnImportantTopicInPython"))


24. import re
def sequence(input):
        seq_check = '[A-Z]+[a-z]+$'
        if re.search(seq_check, input):
                return 'got sequence'
        else:
                return('didnt get the squence')


print(sequence("Is there a SequenceMatch"))

25. import re

def remove_duplicates(input):
 
    
    regex = r'\b(\w+)(?:\W+\1\b)+'
 
    return re.sub(regex, r'\1', input)

sample = "Hello hello world world"
print(remove_duplicates(sample))

26. import re

pattern = '[a-zA-z0-9]$'

def check(input):

    if(re.search(pattern, input)):
        print("Correct")
         
    else:
        print("Incorrect")
        

     
sample = "Thor3456"  
sample1 = "Thor."
check(sample) 
check(sample1)

27. import re
string = """RT @kapil_kausik: #Doltiwal I mean #xyzabc is "hurt" by #Demonetization as the same has rendered USELESS <ed><U+00A0><U+00BD><ed><U+00B1><U+0089> "acquired funds" No wo"""
a=re.findall(r"#(\w+)", string)
print(a)


28.  import re

def rem_pattern(text):
    pattern = r"<U.....>"
    edited_txt = re.sub(pattern,"", text)
    return edited_txt


s1 =  "@Jags123456 Bharat band on 28??<ed><U+00A0><U+00BD><ed><U+00B8><U+0082>Those who  are protesting #demonetization  are all different party leaders"

print(rem_pattern(s1))



29. import re
file = open("29_ass4.txt", "r")
readfile =file.read()
print(re.findall(r'\d+-\d+-\d+',readfile))

30. import re
example = "The following example creates an ArrayList with a capacity of 50 elements. 4 elements are then added to the ArrayList and the ArrayList is trimmed accordingly."

input = re.compile(r'\W*\b\w{2,4}\b')
print(input.sub('', example))
